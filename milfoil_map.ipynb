# %%
import pandas as pd
import numpy as np
import folium

df = pd.read_csv('milfoil_tableB_all_years_cleaned.csv')
df
# Out:
#        id  sample_point   latitude  longitude milfoil_presence  year
# 0       0             1  42.977652 -75.887120                M  2008
# 1       1             2  42.977520 -75.887213                S  2008
# 2       2             3  42.977661 -75.887699                M  2008
# 3       3             4  42.977674 -75.888337                M  2008
# 4       4             5  42.977542 -75.889355                M  2008
# ...   ...           ...        ...        ...              ...   ...
# 4555  299           300  42.960420 -75.871387              NaN  2022
# 4556  300           301  42.961219 -75.871882              NaN  2022
# 4557  301           302  42.961837 -75.872214              NaN  2022
# 4558  302           303  42.948490 -75.866480              NaN  2022
# 4559  303           304  42.948360 -75.866510              NaN  2022
#
# [4560 rows x 6 columns]

# %%
lake_map_2008 = folium.Map(location=[42.950253, -75.870825], zoom_start=13)
lake_map_2008
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abf26a457314a614bea1fb7f860045f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abf26a457314a614bea1fb7f860045f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abf26a457314a614bea1fb7f860045f8 = L.map(
#                 &quot;map_abf26a457314a614bea1fb7f860045f8&quot;,
#                 {
#                     center: [42.950253, -75.870825],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_95f7b27599a4012a4cf9f213f389a0a5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_abf26a457314a614bea1fb7f860045f8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df['milfoil_presence'].unique()
# Out:
# array(['M', 'S', 'D', nan, 'T'], dtype=object)

# %%
df['milfoil_presence'] = df['milfoil_presence'].fillna('N')
df
# Out:
#        id  sample_point   latitude  longitude milfoil_presence  year
# 0       0             1  42.977652 -75.887120                M  2008
# 1       1             2  42.977520 -75.887213                S  2008
# 2       2             3  42.977661 -75.887699                M  2008
# 3       3             4  42.977674 -75.888337                M  2008
# 4       4             5  42.977542 -75.889355                M  2008
# ...   ...           ...        ...        ...              ...   ...
# 4555  299           300  42.960420 -75.871387                N  2022
# 4556  300           301  42.961219 -75.871882                N  2022
# 4557  301           302  42.961837 -75.872214                N  2022
# 4558  302           303  42.948490 -75.866480                N  2022
# 4559  303           304  42.948360 -75.866510                N  2022
#
# [4560 rows x 6 columns]

# %%
df2008 = df.loc[df.year == 2008]
df2008
# Out:
#       id  sample_point   latitude  longitude milfoil_presence  year
# 0      0             1  42.977652 -75.887120                M  2008
# 1      1             2  42.977520 -75.887213                S  2008
# 2      2             3  42.977661 -75.887699                M  2008
# 3      3             4  42.977674 -75.888337                M  2008
# 4      4             5  42.977542 -75.889355                M  2008
# ..   ...           ...        ...        ...              ...   ...
# 297  297           298  42.959125 -75.870077                M  2008
# 298  298           299  42.959650 -75.870627                D  2008
# 299  299           300  42.960420 -75.871387                D  2008
# 300  300           301  42.961219 -75.871882                D  2008
# 301  301           302  42.961837 -75.872214                D  2008
#
# [302 rows x 6 columns]

# %%
# none, trace, sparse, moderate, dense
milfoil_abundance = ['N', 'T', 'S', 'M', 'D'] # use index for number value

for ma_index, value in enumerate(milfoil_abundance):
  for df_index, row in df2008.iterrows():
    print(df_index) # 0, 1, 2 ... 302, 303
    # print(df2008.index)
    print(df2008.milfoil_presence)

# for ma_index, value in enumerate(milfoil_abundance):
#   for df_index, presence in enumerate(df.milfoil_presence):
#     if presence == value:
#       print(ma_index, df['latitude'][df_index], df['longitude'][df_index])
# Out:
# 0
# 0      M
# 1      S
# 2      M
# 3      M
# 4      M
#       ..
# 297    M
# 298    D
# 299    D
# 300    D
# 301    D
# Name: milfoil_presence, Length: 302, dtype: object
# 1
# 0      M
# 1      S
# 2      M
# 3      M
# 4      M
#       ..
# 297    M
# 298    D
# 299    D
# 300    D
# 301    D
# Name: milfoil_presence, Length: 302, dtype: object
# 2
# 0      M
# 1      S
# 2      M
# 3      M
# 4      M
#       ..
# 297    M
# 298    D
# 299    D
# 300    D
# 301    D
# Name: milfoil_presence, Length: 302, dtype: object
# 3
# 0      M
# 1      S
# 2      M
# 3      M
# 4      M
#       ..
# 297    M
# 298    D
# 299    D
# 300    D
# 301    D
# Name: milfoil_presence, Length: 302, dtype: object
# 4
# 0      M
# 1      S
# 2      M
# 3      M
# 4      M
#       ..
# 297    M
# 298    D
# 299    D
# 300    D
# 301    D
# Name: milfoil_presence, Length: 302, dtype: object
#
# 0      M
# 1      S
# 2      M
# 3      M
# 4      M
#       ..
# 297    M
# 298    D
# 299    D
# 300    D
# 301    D
# Name: milfoil_presence, Length: 302, dtype: object
# 293
# 0      M
# 1      S
# 2      M
# 3      M
# 4      M
#       ..
# 297    M
# 298    D
# 299    D
# 300    D
# 301    D
# Name: milfoil_presence, Length: 302, dtype: object
# 294
# 0      M
# 1      S
# 2      M
# 3      M
# 4      M
#       ..
# 297    M
# 298    D
# 299    D
# 300    D
# 301    D
# Name: milfoil_presence, Length: 302, dtype: object
# 295
# 0      M
# 1      S
# 2      M
# 3      M
# 4      M
#       ..
# 297    M
# 298    D
# 299    D
# 300    D
# 301    D
# Name: milfoil_presence, Length: 302, dtype: object
# 296
# 0      M
# 1      S
# 2      M
# 3      M
# 4      M
#       ..
# 297    M
# 298    D
# 299    D
# 300    D
# 301    D
# Name: milfoil_presence, Length: 302, dtype: object
# 297
# 0      M
# 1      S
# 2      M
# 3      M
# 4      M
#       ..
# 297    M
# 298    D
# 299    D
# 300    D
# 301    D
# Name: milfoil_presence, Length: 302, dtype: object
# 298
# 0      M
# 1      S
# 2      M
# 3      M
# 4      M
#       ..
# 297    M
# 298    D
# 299    D
# 300    D
# 301    D
# Name: milfoil_presence, Length: 302, dtype: object
# 299
# 0      M
# 1      S
# 2      M
# 3      M
# 4      M
#       ..
# 297    M
# 298    D
# 299    D
# 300    D
# 301    D
# Name: milfoil_presence, Length: 302, dtype: object
# 300
# 0      M
# 1      S
# 2      M
# 3      M
# 4      M
#       ..
# 297    M
# 298    D
# 299    D
# 300    D
# 301    D
# Name: milfoil_presence, Length: 302, dtype: object
# 301
# 0      M
# 1      S
# 2      M
# 3      M
# 4      M
#       ..
# 297    M
# 298    D
# 299    D
# 300    D
# 301    D
# Name: milfoil_presence, Length: 302, dtype: object

# %%
for ma_index, value in enumerate(milfoil_abundance):
  for df_index, row in df2008.iterrows():
    if row['milfoil_presence'] == value:
      # print(row['latitude'], type(row['latitude']), row['longitude'], type(row['longitude']))
      folium.features.CircleMarker(
        [row['latitude'], row['longitude']],
        radius=ma_index*2,
        color=None, #'green', 
        fill_color='green', 
        fill_opacity=0.5,
    ).add_to(lake_map_2008)
lake_map_2008
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abf26a457314a614bea1fb7f860045f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abf26a457314a614bea1fb7f860045f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abf26a457314a614bea1fb7f860045f8 = L.map(
#                 &quot;map_abf26a457314a614bea1fb7f860045f8&quot;,
#                 {
#                     center: [42.950253, -75.870825],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_95f7b27599a4012a4cf9f213f389a0a5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_abf26a457314a614bea1fb7f860045f8);
#
#
#             var circle_marker_1b8be65426288b00f8d47975df915c32 = L.circleMarker(
#                 [42.9750457, -75.8874802],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abf26a457314a614bea1fb7f860045f8);
#
#
#             var circle_marker_0be63f94e391c779d49d768c46bbf28f = L.circleMarker(
#                 [42.972166, -75.8825192],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abf26a457314a614bea1fb7f860045f8);
#
#
#             var circle_marker_ea9d26dc8b9ca557c2d163ac3f7fc5d3 = L.circleMarker(
#                 [42.9722997, -75.8813674],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abf26a457314a614bea1fb7f860045f8);
#
#
#             var circle_marker_1f8dc87671aeca03e951f96ec2de131a = L.circleMarker(
#                 [42.9716923, -75.8804835],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abf26a457314a614bea1fb7f860045f8);
#
#
#             var circle_marker_b6b328de5f5b9c45bfd92e82d8accc14 = L.circleMarker(
#                 [42.9707304, -75.8809406],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abf26a457314a614bea1fb7f860045f8);
#
#
#             var circle_marker_99414a9fc9b84ccc1f50a0e351a5ccd0 = L.circleMarker(
#                 [42.9640562, -75.8771422],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_abf26a457314a614bea1fb7f860045f8);
#
#
#             var circle_marker_6bc7a2d6f91dc6a2308f1ea851304d17 = L.circleMarker(
#                 [42.963495, -75.8750705],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot

# %%
df2009 = df.loc[df.year == 2009]
lake_map_2009 = folium.Map(location=[42.950253, -75.870825], zoom_start=13)
df2009
# Out:
#       id  sample_point   latitude  longitude milfoil_presence  year
# 302    0             1  42.977680  75.886960                S  2009
# 303    1             2  42.977520  75.887213                S  2009
# 304    2             3  42.977661  75.887699                T  2009
# 305    3             4  42.977674  75.888337                N  2009
# 306    4             5  42.397754  75.889355                N  2009
# ..   ...           ...        ...        ...              ...   ...
# 601  299           300  42.960420  75.871387                N  2009
# 602  300           301  42.961219  75.871882                N  2009
# 603  301           302  42.961837  75.872214                N  2009
# 604  303           303  42.948490  75.866480                M  2009
# 605  304           304  42.948360  75.866510                M  2009
#
# [304 rows x 6 columns]

# %%
# none, trace, sparse, moderate, dense
# milfoil_abundance = ['N', 'T', 'S', 'M', 'D'] # use index for number value
for ma_index, value in enumerate(milfoil_abundance):
  for df_index, presence in df2009.iterrows():
    print(df_index) # 0, 1, 2 ... 302, 303
    # print(df2009.index)
    print(df2009.milfoil_presence)
# Out:
# 302
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
#
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 587
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 588
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 589
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 590
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 591
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 592
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 593
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 594
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 595
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 596
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 597
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 598
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 599
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 600
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 601
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 602
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 603
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 604
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object
# 605
# 302    S
# 303    S
# 304    T
# 305    N
# 306    N
#       ..
# 601    N
# 602    N
# 603    N
# 604    M
# 605    M
# Name: milfoil_presence, Length: 304, dtype: object

# %%
for ma_index, value in enumerate(milfoil_abundance):
  for df_index, row in df2009.iterrows():
    # print(row['id'], row['milfoil_presence'])

    if row['milfoil_presence'] == value:
      if ma_index > 0:
        # print(row['milfoil_presence'], ma_index) # should have 124 circles: 38 T, 67 S, 17 M, 2 D
        # print(row['latitude'], type(row['latitude']), row['longitude']*-1, type(row['longitude']))
        folium.features.CircleMarker(
          [row['latitude'], row['longitude']*-1],
          radius=ma_index*2,
          color=None,
          fill_color='green', 
          fill_opacity=0.5,
        ).add_to(lake_map_2009)
lake_map_2009
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5e79b33fe5ca614e96b82ab81edccae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5e79b33fe5ca614e96b82ab81edccae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5e79b33fe5ca614e96b82ab81edccae = L.map(
#                 &quot;map_c5e79b33fe5ca614e96b82ab81edccae&quot;,
#                 {
#                     center: [42.950253, -75.870825],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4948c16938921d9ed669081c9af06702 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c5e79b33fe5ca614e96b82ab81edccae);
#
#
#             var circle_marker_b180d0166a032162432a54c7b09ea706 = L.circleMarker(
#                 [42.9776614, 75.887699],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c5e79b33fe5ca614e96b82ab81edccae);
#
#
#             var circle_marker_16bad0d7e570e1b73411a5c7408d33ca = L.circleMarker(
#                 [42.9748581, 75.89047],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c5e79b33fe5ca614e96b82ab81edccae);
#
#
#             var circle_marker_fc53fced105fd402fa61872e7ae6ecdc = L.circleMarker(
#                 [42.9752415, 75.8825262],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c5e79b33fe5ca614e96b82ab81edccae);
#
#
#             var circle_marker_7a1250e8b2bb3d378b2b182f696c6fa7 = L.circleMarker(
#                 [42.9705937, 75.8828932],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c5e79b33fe5ca614e96b82ab81edccae);
#
#
#             var circle_marker_5c367b11bc52a8118e7ed184245735f0 = L.circleMarker(
#                 [42.9657158, 75.8754783],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c5e79b33fe5ca614e96b82ab81edccae);
#
#
#             var circle_marker_c7e00e576103edb05f714bddbb0e61db = L.circleMarker(
#                 [42.9646037, 75.8746784],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: null, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c5e79b33fe5ca614e96b82ab81edccae);
#
#
#             var circle_marker_097118f5b1bdd6fcc52f07c97dff89e3 = L.circleMarker(
#                 [42.9577861, 75.8771686],
#                 {&quot;bubblingMouseEve

# %%
df_from_2009_csv = pd.read_csv('milfoil_2009_only.csv')
df_from_2009_csv
# Out:
#       id  sample_point   latitude  longitude milfoil_presence  year
# 0      0             1  42.977680  75.886960                S  2009
# 1      1             2  42.977520  75.887213                S  2009
# 2      2             3  42.977661  75.887699                T  2009
# 3      3             4  42.977674  75.888337              NaN  2009
# 4      4             5  42.397754  75.889355              NaN  2009
# ..   ...           ...        ...        ...              ...   ...
# 299  299           300  42.960420  75.871387              NaN  2009
# 300  300           301  42.961219  75.871882              NaN  2009
# 301  301           302  42.961837  75.872214              NaN  2009
# 302  303           303  42.948490  75.866480                M  2009
# 303  304           304  42.948360  75.866510                M  2009
#
# [304 rows x 6 columns]
